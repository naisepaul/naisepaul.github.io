# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt
coder_df= pd.read_csv("D:/coder.csv")
coder_df.head(5)
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# ...

# %%
coder_df = coder_df[['Age','CountryCitizen','CountryLive','ExpectedEarning','Gender','Income','MoneyForLearning','MonthsProgramming','SchoolDegree']]
coder_df.head(10)
# Out:
#     Age            CountryCitizen               CountryLive  ExpectedEarning  \
# 0  28.0  United States of America  United States of America              NaN
# 1  22.0  United States of America  United States of America          50000.0
# 2  19.0  United States of America  United States of America              NaN
# 3  26.0  United States of America  United States of America          65000.0
# 4  20.0  United States of America  United States of America          45000.0
# 5  34.0  United States of America  United States of America              NaN
# 6  23.0                 Singapore                 Singapore              NaN
# 7  35.0                     India            United Kingdom              NaN
# 8  33.0  United States of America  United States of America              NaN
# 9  33.0  United States of America  United States of America              NaN
#
#    Gender   Income  MoneyForLearning  MonthsProgramming  \
# 0    male  32000.0               0.0                1.0
# ...

# %%
coder_df.describe()
# Out:
#                 Age  ExpectedEarning         Income  MoneyForLearning  \
# count  13613.000000      6077.000000    7329.000000      14679.000000
# mean      29.175421     53717.586967   44930.010506       1108.010559
# std        9.017716     30078.511957   35582.783216       4860.825612
# min       10.000000      6000.000000    6000.000000          0.000000
# 25%             NaN              NaN            NaN               NaN
# 50%             NaN              NaN            NaN               NaN
# 75%             NaN              NaN            NaN               NaN
# max       86.000000    200000.000000  200000.000000     180000.000000
#
#        MonthsProgramming
# count       15014.000000
# mean           24.430198
# std            49.426744
# min             0.000000
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max           720.000000

# %%
coder_df['CountryCitizen'].value_counts()
# Out:
# United States of America         5976
# India                            1154
# United Kingdom                    542
# Canada                            495
# Brazil                            299
# Russia                            268
# Ukraine                           254
# Poland                            239
# Australia                         232
# Germany                           208
# Romania                           160
# France                            151
# Spain                             144
# Mexico                            139
# Italy                             133
# Netherlands (Holland, Europe)     131
# Nigeria                           121
# Philippines                       119
# South Africa                      103
# Portugal                           95
# Indonesia                          88
# China                              81
# Greece                             78
# Argentina                          77
# Malaysia                           73
# ...

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize= (8,4))
ax1 =set_xlabel('No of Coders')
ax1 =set_ylabel('Gender')
ax1 =set_title("Gender Distribution")
temp1.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-051388150963> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 fig = plt.figure(figsize= (8,4))
# ----> 3 ax1 =set_xlabel('No of Coders')
#       4 ax1 =set_ylabel('Gender')
#       5 ax1 =set_title("Gender Distribution")
#
# NameError: name 'set_xlabel' is not defined

# %%
print coder_df['Age'].mean()
print coder_df['MonthsProgramming'].mean()
# Out:
# 29.1754205539
# 24.4301984814

# %%
print coder_df['Age'].median()
print coder_df['MonthsProgramming'].median()
# Out:
# 27.0
# 9.0

# %%
print coder_df['Age'].var()
print coder_df['MonthsProgramming'].var()
# Out:
# 81.3192106757
# 2443.00302058

# %%
print coder_df['Age'].std()
print coder_df['MonthsProgramming'].std()
# Out:
# 9.01771648898
# 49.4267439812
